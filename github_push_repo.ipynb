# %%
from google.colab import drive, userdata
import os

drive.mount("/content/drive")

# CLEAN WRONG GIT REPO CREATED IN /content
# %cd /content
# !rm -rf .git
# !rm -f .gitignore

# LOAD TOKEN
GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
assert GITHUB_TOKEN is not None, "GITHUB_TOKEN not found in Colab Secrets."
os.environ["GITHUB_TOKEN"] = GITHUB_TOKEN

# GO TO CORRECT REPO ROOT
# %cd "/content/drive/MyDrive/Colab Notebooks/Education/NLP/Natural-Language-Processing"

# SAFETY CHECK
# !pwd
# !ls
# !git status || true

# CREATE .gitignore SAFELY
with open(".gitignore", "w") as f:
    f.write("""__pycache__/
*.pyc
.ipynb_checkpoints/
.env
*.key
*.pem
kaggle.json
wandb/
data/
datasets/
raw/
*.pt
*.pth
*.ckpt
*.h5
*.onnx
*.tflite
checkpoints/
models/
.DS_Store
Thumbs.db
""")

# INIT + PUSH
# !git init
# !git branch -M main

# !git remote remove origin 2>/dev/null || true
# !git remote add origin https://github.com/YBenjaminPCondori/Natural-Language-Processing.git

# !git config user.name "YBenjaminPCondori"
# !git config user.email "y.benjamin_pc@hotmail.com"

# !git status --short
# !git add .
# !git commit -m "Update NLP coursework repository" || echo "Nothing new to commit"
# !git push https://YBenjaminPCondori:${GITHUB_TOKEN}@github.com/YBenjaminPCondori/Natural-Language-Processing.git main

# %%
# !pkill -f "git push" || true
# !pkill -f "git add" || true
# !rm -f .git/index.lock
# Out:
# ^C
# ^C
